# %% [markdown]
# <a href="https://colab.research.google.com/github/sr606/Python-Practice/blob/main/P%26Distribution2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Content
# Topic 2: Introduction, Population vs Sample
#
# Topic 3: Sample statistics
#
# Topic 4: Quiz 1 explanation
#
# Topic 5: Point Estimates, Sampling techniques, Standard error
#
# Topic 6: Break & Doubt Resolution
#
# Topic 7: Standard Error
#
# Topic 8: Quiz 2 explanation
#
# Topic 9: Uniform distribution
#
# Topic 10: Quiz 3 explanation
#
# Topic 11: Visualisation and properties
# of Uniform distribution
#
# Topic 12: Conclusion
#
# Topic 13: Practice Question
#
# Topic 14: Doubt Resolution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# pt estimatio is we telling someone that on basis of sample we have this much data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Probability sampling : e.g: tea loversin banglore/india
#
#
#
# Non-Probability : miss. universe, covid 19/outbreak of any disease

# %% [markdown]
# ![image.png](data:image/png;base64,...)
