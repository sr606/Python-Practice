# %% [markdown]
# <a href="https://colab.research.google.com/github/sr606/Python-Practice/blob/main/Oct24_DV_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Content**
#
#
# Intro to Matplotlib & Seaborn
#
# Tecent Use Case
#
# Anatomy of Matplotlib
#
#
# Components of a Matplotlib plot
#
# Univariate Data Visualisation
#
#
#
#
# *   Categorical
#
#
# Bar, Countplot, Pie chart
#
# *   Continuous
#
# Histogram, KDE Plot, Box and Whiskers plot

# %%
#matplotlib has sub module pyplot no need to import whole library
#pyplot is for visulization in matplotlib
#hihglevel API which makes plotting easy task

# %%
#Diffrenence between matplotlib and seaborn

#built on top of Pandas and Matplotlib
#seaborn uses fascinating themes and reduce no. of code lines by doing work in backend
#matplotlib used to plot basic plots and add functionality on top of that

# %%
#why we need visualization
#exploratory = I cant see certain patterns just by crunching no.s(avg, rates, %ages)
#Explanatory = have no.s crunches and insights ready, but would like a visual art for
#storytelling


#why we using python for data visualisation

#soemtimes it is slow to use other platforms, with python u can push large data set
# customization, certain limitations
# data is sensetive it gets leaks to other platform
#some quantom of data exposed to other platform - sesitivity of data

# %%
#Data  ==> 1.Numerical(continuous), 2. Categorical ===>>>i.Ordinal(e,g months) ii.Non-Ordinal/Nominal

# %%
#1. Line plot - two diff data need to see visualization between them, e.g.stock price plot

#2, scatterplot  - where largest cluster is present, area vs pop

#3. Bar chart - categircal data

#4, stacked  - one above other categories


#5. dodged bar chart

#. Histogram

#7 Pie chart


#8 Density chart

#9. Box plot and whiskers plot

#10. violoin

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O final_vg.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/final_vg.csv
# 100% 2.04M/2.04M [00:00<00:00, 30.4MB/s]

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('final_vg.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
len(data['Year'].value_counts()) # different yrs value
# Out:
# 41

# %%
len(data)
# Out:
# 16652

# %%
len(data['Rank'].value_counts())
# Out:
# 16598

# %% [markdown]
# Whay are th epossible Cases?
#
#
# Univariate
#
#
#
# *   Numercial
# *   Categorical
#
#
#
# Bivariate
#
#
#
#
# *   Numerical - Numerical
# *   Numerical - Categorical
# *   Categorical - Categorical
#
#
#
# Multivariate
#
#
# Let's start with these & then we can genralize
#
#
#
#
# *   Num - Num - Cat
# *   Cat - Cat - Num
# *   Cat - Cat - Cat
# *   Num - Num - Num

# %%
x = [0, 1, 2]
y = [3, 5 ,9]
plt.plot(x, y)

# %%
len(data['Genre'].value_counts())
# Out:
# 12

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
cnt = data['Genre'].value_counts()

x_bar = cnt.index
y_bar = cnt
plt.bar(x_bar, y_bar)
# Out:
# <BarContainer object of 12 artists>

# %%
cnt = data['Genre'].value_counts()

x_bar = cnt.index
y_bar = cnt
plt.bar(x_bar, y_bar)
plt.show()

# %%
cnt = data['Genre'].value_counts()

x_bar = cnt.index
y_bar = cnt

plt.figure(figsize = (12, 6))
plt.bar(x_bar, y_bar)
plt.show()

# %%
plt.figure(figsize = (9, 6))
plt.bar(x_bar, y_bar)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.bar(x_bar, y_bar)
plt.xticks(rotation = 45)
plt.show()

# %%
plt.bar(x_bar, y_bar, width = 0.5, color = 'orange')
plt.title('Games per Genre')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.bar(x_bar, y_bar, width = 0.5, color = 'orange')
plt.title('Games per Genre')
plt.xlabel('Genre', fontsize = 12)
plt.ylabel('Count', fontsize = 15)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.countplot(x = 'Genre',
              data = data,
              order = data['Genre'].value_counts().index,
              color = 'cornflowerblue')
plt.xticks(rotation = 90)
plt.show()

# %%
sales_data = data[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
sales_data
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0      4.569217  3.033887  3.439352     1.991671
# 1      2.076955  1.493442  3.033887     0.394830
# 2      1.145709  1.762339  1.493442     0.408693
# 3      2.031986  1.389856  3.228043     0.394830
# 4      2.792725  2.592054  1.440483     1.493442
# ...         ...       ...       ...          ...
# 16647  4.409308  3.167419  4.168474     1.087977
# 16648  3.033887  2.792725  1.596852     1.493442
# 16649  3.228043  2.004268  1.833151     1.087977
# 16650  1.087977  0.592445  1.087977     0.394830
# 16651  1.081046  1.714664  2.004268     0.394830
#
# [16652 rows x 4 columns]

# %%
region_sales = sales_data.T.sum(axis='columns')
region_sales
# Out:
# NA_Sales       45831.525845
# EU_Sales       33251.970702
# JP_Sales       41624.625635
# Other_Sales    19180.256828
# dtype: float64

# %%
plt.pie(region_sales)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa7c10aae30>,
# ...
#  [Text(0.5669817295808993, 0.9426196042526657, ''),
#   Text(-1.038391432883245, 0.3629645053096531, ''),
#   Text(-0.24595114437892593, -1.0721511248787163, ''),
#   Text(0.9995192958546524, -0.4593051025344918, '')])

# %%
plt.pie(region_sales, labels = region_sales.index)
plt.show()

# %%
plt.pie(region_sales,
        labels = region_sales.index,
        startangle = 90,
        autopct = '%0.1f%%')
plt.show()

# %%
plt.pie(region_sales,
        labels = region_sales.index,
        startangle = 90,
        explode = [0.1, 0.1, 0, 0],
        autopct = '%0.1f%%')
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Histogram

# %%
plt.hist(data['Year'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data['Year'],bins = 4)
plt.show()

# %%
sns.histplot(data['Year'], bins =10)

# seaborn is little better than matplotlib it is giving labels without asking
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# #KDE plot
#
#
#
# same as histogram but dat is represent in form line representing data using PDF

# %%
sns.kdeplot(data['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %% [markdown]
# ###Boxplot

# %%
data['Global_Sales']
# Out:
# 0        12.802935
# 1         7.034163
# 2         4.982552
# 3         7.226880
# 4         8.363113
#            ...
# 16647    13.053204
# 16648     8.878837
# 16649     7.954274
# 16650     3.509168
# 16651     5.132196
# Name: Global_Sales, Length: 16652, dtype: float64

# %%
sns.boxplot(y = data['Global_Sales'])
# Out:
# <Axes: ylabel='Global_Sales'>

# %%
#helps to categorize(100= 25, 25, 25, 25= 4 quadrants )
#median, mean, percentile
#e.g i want typical earnings of game when it is published
#box and whistlers plot = shoes distribution of quantitive data

#what is whiskers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data["Global_Sales"])
plt.yticks(fontsize=20)
plt.ylabel('Global Sales (in million dollars)', fontsize=20)
plt.title('Global Sales of video games', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Global Sales of video games')

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data = data, x = 'Genre', y = 'Global_Sales')
plt.title('Global Sales of video games', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Global Sales of video games')
