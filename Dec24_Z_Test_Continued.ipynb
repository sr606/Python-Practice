# %% [markdown]
# <a href="https://colab.research.google.com/github/sr606/Python-Practice/blob/main/Dec24_Z_Test_Continued.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.stats import weightstats as stests
from scipy import stats

# %%
z_score, pval = stests.ztest(x1 = M1_data, x2 = M2_data, value = 0, alternative = 'two-sided')

print("Z-Score:", z_score)
print("p-value:", pval)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e95da239b85b> in <cell line: 1>()
# ----> 1 z_score, pval = stests.ztest(x1 = M1_data, x2 = M2_data, value = 0, alternative = 'two-sided')
#       2
#       3 print("Z-Score:", z_score)
#       4 print("p-value:", pval)
#
# NameError: name 'M1_data' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# H0 = avg fuel effeciency is same for both engines
#
# mue1 = mu2

# %% [markdown]
# Ha = avg effiency is not same for both
#
# mu1 != mu2

# %%
import numpy as np

# %%
def TwoDampZTest(samp_mean_1, samp_mean_2, samp_std_1, samp_std2, n1 , n2):
  #Calculate the test statastic
  denominator = np.sqrt((samp_std_1**2 / 2) + (samp_std_2**2 / 2))

# %%
M1_data = [162, 164, 168, 170, 174, 176, 180, 182, 186, 188, 192, 194, 198, 200, 204, 206, 210, 212, 216, 218, 222, 224, 228, 230, 234, 236, 240, 242, 246, 248, 252, 254, 258, 260, 264, 266, 270]
M2_data = [158, 162, 166, 170, 174, 178, 182, 186, 190, 194, 198, 202, 206, 210, 214, 218, 222, 226, 230, 234, 238, 242, 246, 250, 254, 258, 262, 266, 270, 274, 278, 282, 286, 290, 294, 298, 302]

# %%
alpha = 0.1

# %%
stests.ztest(x1 = M1_data, x2 = M2_data, value = 0, alternative = 'two-sided')
# Out:
# (-1.6280691715301856, 0.10351021950900992)

# %%
# Number of dissatisfied customers
x = 65
# Total number of customers in the sample
n = 250

# Specify the target satisfaction level (null hypothesis)
target_satisfaction = 0.30#0  # 70%

# %%
p = target_satisfaction # population proportion

# Calculate the test statistic (Z)
# p_hat = sample proportion = x/n
p_hat = x / n

# %%
Z = (p_hat - p) / np.sqrt((p * (1 - p)) / n)

# Interpret the test statistic
# Z follows a standard normal distribution. We will calculate the two-tailed p-value next.

# Calculate the p-value
p_value = 2 * (1 - stats.norm.cdf(np.abs(Z)))

p_value
# Out:
# 0.1675462774886176

# %%
n1 = 1000
n2 = 500
x1 = 50
x2 = 30

#H0 ===> p1 = p2
# Ha ===> p1!= p2

#normal distribution

#two-tailed test
