# %% [markdown]
# <a href="https://colab.research.google.com/github/sr606/Python-Practice/blob/main/Introduction_to_Hypothesis_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Agenda**
#
# Hypothesis Testing
#
# Hypo Testing Terminologies
#
# Types of Error
#
# Tailed Tests
#
# Deep dive in COin Toss Ex
#
# Hypothesis Testing Framework

# %% [markdown]
# ###**Ex of Hypothesis(Assumption)**
#
# Flipkart
#
#
# Impact ---> +ve impact or decrease in sales
#
# No Impact

# %% [markdown]
# Coin Toss
#
#
# Default Assumption --> Fair Coin/Unbaised
#
# we need some data to show that coin is not fair
#
#
#
# We need to start with Assumption for Hypothesis tetsing always
#
#
#
# Simple basic way to test it we need to toss it multiple times
#
#
# If we toss 10 times ----> 7 times we get head
#
#
#
#
# This isnt enough to say ir test our assumption is right or wrong
#
#
# We need more sample
#
#
# Lets go 100 times ---> 70 times Heads
#
#
# This is also not enough to prove or test our assumotion
#
#
# 1000 -- > 700 times Heads
#
#
# This is enough to prove that this coin is baised

# %% [markdown]
# ###**Eg2**
#
# Judge in court room
#
# Default --> Innocent until proven guilty
#
#
# Data -->
#
# 1.  Person was on crime scene --not sure
#
# 2.  Had a knife -- might be
#
# 3.  Fingerprint were found on dead body -- can think of
#
# 4.  CCTV --- like this proofs are increasing we getting confidence

# %% [markdown]
# Null Hypothesis -- H0 -- Default Hypothesis
#
#
# Alternate Hypothesis (Ha/H1) -- Assumption other than default
#
# H0 --> x = 5
#
# Ha--> x!= 5  or Ha --> x> 5

# %% [markdown]
# ##**P VAlue**
#
#
# prob of obtaining results at least extreme as the rsults observed, under assumption null hypo is correct
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Low p value reject Null Hypothesis

# %% [markdown]
# ##**Confidence/ Significance level**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In above ex judge is 75 % confident that person is guilty but this wont work he has to be 99% sure abt it as alpha is 0.01

# %% [markdown]
# p- value < alpha ==> reject **H0**

# %% [markdown]
# ##**Types Of Errors**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Type 2 Error == person is guilty but judge is saying he is innocent (False- Negative)
# You r actually pregnent but it proved that u r not
#
#
#
# Type 1 Error == Person is innocent but judge issaying he is guilty(False -positive)
#
# U r not prgnent but but it is proven that u are pregnant
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Tailed Tests**
#
# Left Tailed Test
#
#
# H0--> mue = 200
#
# Ha--> mue < 200
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Right Tailed Test
#
#
# ML model
#
#
# old model has accuracy of --> 90% (H0)
#
#
# Now we have new model u want to pmove it to production what u need to prove
#
# H1 -- > accuracy > 90% (of new model).
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Two Tailed Test
#
#
# H0 - avg height = 65 inches
#
# H1 - avg height != 65 inches
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
1 + 1
# Out:
# 2

# %%
# 10 coin toss -> 7 are heads

from scipy.stats import binom

1 - binom.cdf(k=6, n=10, p=0.5)
# Out:
# 0.171875
